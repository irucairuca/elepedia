# %%
### 複数のグラフを重ねて表示
import numpy as np
import matplotlib.pyplot as plt
import math

t = np.linspace(0, 10, 1000)

V=100
I=10
f=50

a= float(input("位相nπを入力してください"))
alpha = math.pi*a


y1 = 2**0.5*V*np.sin(2*math.pi*t)
y2 = 2*0.5*I*np.sin(2*math.pi*t-alpha) 
y3=y1*y2

c1, c2,c3 = 'blue', 'green','red'
l1, l2 ,l3= 'v', 'i','p'

xl = 'x'
yl = 'y'


fig = plt.figure()

plt.plot(x, y1, color=c1, label=l1)
plt.plot(x, y2, color=c2, label=l2)
plt.plot(x, y3, color=c3, label=l3)

#ラベルを追加
plt.xlabel(xl)
plt.ylabel(yl)


# 凡例表示
plt.legend(loc = 'upper right') 

plt.show()
# Out:
# 位相nπを入力してください0.5
